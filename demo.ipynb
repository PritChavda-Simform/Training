# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('employee_attrition_dataset.csv')

# %%
df.drop('Employee_ID',axis=1)
# Out:
#      Age  Gender Marital_Status Department   Job_Role  Job_Level  \
# 0     58  Female        Married         IT    Manager          1
# 1     48  Female        Married      Sales  Assistant          5
# 2     34    Male        Married  Marketing  Assistant          1
# 3     27  Female       Divorced  Marketing    Manager          1
# 4     40    Male       Divorced  Marketing  Executive          1
# ..   ...     ...            ...        ...        ...        ...
# 995   27  Female       Divorced         HR    Analyst          2
# 996   47    Male         Single         IT    Manager          4
# 997   50  Female       Divorced         IT  Executive          1
# 998   28  Female        Married         HR  Executive          4
# 999   48  Female       Divorced         IT    Analyst          2
#
#      Monthly_Income  Hourly_Rate  Years_at_Company  Years_in_Current_Role  \
# 0             15488           28                15                      4
# ...

# %%
len(df.columns)
df.columns
# Out:
# Index(['Employee_ID', 'Age', 'Gender', 'Marital_Status', 'Department',
#        'Job_Role', 'Job_Level', 'Monthly_Income', 'Hourly_Rate',
#        'Years_at_Company', 'Years_in_Current_Role',
#        'Years_Since_Last_Promotion', 'Work_Life_Balance', 'Job_Satisfaction',
#        'Performance_Rating', 'Training_Hours_Last_Year', 'Overtime',
#        'Project_Count', 'Average_Hours_Worked_Per_Week', 'Absenteeism',
#        'Work_Environment_Satisfaction', 'Relationship_with_Manager',
#        'Job_Involvement', 'Distance_From_Home', 'Number_of_Companies_Worked',
#        'Attrition'],
#       dtype='object')

# %%
df.shape
# Out:
# (1000, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Employee_ID                    10000 non-null  int64
#  1   Age                            10000 non-null  int64
#  2   Gender                         10000 non-null  object
#  3   Marital_Status                 10000 non-null  object
#  4   Department                     10000 non-null  object
#  5   Job_Role                       10000 non-null  object
#  6   Job_Level                      10000 non-null  int64
#  7   Monthly_Income                 10000 non-null  int64
#  8   Hourly_Rate                    10000 non-null  int64
#  9   Years_at_Company               10000 non-null  int64
#  10  Years_in_Current_Role          10000 non-null  int64
#  11  Years_Since_Last_Promotion     10000 non-null  int64
# ...

# %%
df.describe()
# Out:
#        Employee_ID           Age     Job_Level  Monthly_Income   Hourly_Rate  \
# count  10000.00000  10000.000000  10000.000000    10000.000000  10000.000000
# mean    5000.50000     39.561800      2.990800    11436.716700     57.032300
# std     2886.89568     11.454986      1.410643     4926.528302     24.703261
# min        1.00000     20.000000      1.000000     3000.000000     15.000000
# 25%     2500.75000     30.000000      2.000000     7182.500000     36.000000
# 50%     5000.50000     40.000000      3.000000    11401.500000     57.000000
# 75%     7500.25000     49.000000      4.000000    15679.500000     78.000000
# max    10000.00000     59.000000      5.000000    19999.000000     99.000000
#
#        Years_at_Company  Years_in_Current_Role  Years_Since_Last_Promotion  \
# count      10000.000000           10000.000000                10000.000000
# mean          14.936200               7.451300                    4.471900
# ...

# %%
df['Job_Role'].value_counts()
# Out:
# Job_Role
# Analyst      2572
# Assistant    2538
# Executive    2476
# Manager      2414
# Name: count, dtype: int64

# %%
df['Department'].value_counts()
# Out:
# Department
# Marketing    2133
# Sales        2008
# Finance      1990
# HR           1953
# IT           1916
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Employee_ID                      0
# Age                              0
# Gender                           0
# Marital_Status                   0
# Department                       0
# Job_Role                         0
# Job_Level                        0
# Monthly_Income                   0
# Hourly_Rate                      0
# Years_at_Company                 0
# Years_in_Current_Role            0
# Years_Since_Last_Promotion       0
# Work_Life_Balance                0
# Job_Satisfaction                 0
# Performance_Rating               0
# Training_Hours_Last_Year         0
# Overtime                         0
# Project_Count                    0
# Average_Hours_Worked_Per_Week    0
# Absenteeism                      0
# Work_Environment_Satisfaction    0
# Relationship_with_Manager        0
# Job_Involvement                  0
# Distance_From_Home               0
# Number_of_Companies_Worked       0
# Attrition                        0
# dtype: int64

# %%
# # sns.boxenplot(df)

# for i in df.columns :
#     plt.figure(figsize=(8,5))
#     plt.subplot()
#     sns.boxenplot(df[i])
#     # plt.legend()
#     plt.show()

# %%
# Define grid layout
num_cols = len(df.columns)
rows = (num_cols // 3) + 1  # Adjust for number of numerical columns
fig, axes = plt.subplots(rows, 3, figsize=(15, 5 * rows))  # Grid with 3 columns per row
axes = axes.flatten()
for i, col in enumerate(df.columns):
    sns.boxplot(df[col],ax=axes[i])
    axes[i].set_title(col)
# Remove extra empty subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])
 
plt.tight_layout()  # Adjust spacing
plt.show()


num_cols = len(df.columns)

rows = (num_cols // 3) + 1 
fig,axes = plt.subplot(rows,3,figsize = (15,5 * rows))
axes = axes.flatten()
for i, col in eumerte(df.columns):
    sns.boxenplot(df[col], ax=axes[i])
    axes[i].set_title(col)

for j in rage(i + 1, len(axes)):
    fig.delaxes(axes[j])


plt.tight_layout()
plt.show()

num_cols = len(df.columns)

rows = (num_cols //3) + 1
fig,axes = plt.subplt(rows,3 , figsize = (15,5 * rows))

# %%
df.describe()
# Out:
#        Employee_ID           Age     Job_Level  Monthly_Income   Hourly_Rate  \
# count  10000.00000  10000.000000  10000.000000    10000.000000  10000.000000
# mean    5000.50000     39.561800      2.990800    11436.716700     57.032300
# std     2886.89568     11.454986      1.410643     4926.528302     24.703261
# min        1.00000     20.000000      1.000000     3000.000000     15.000000
# 25%     2500.75000     30.000000      2.000000     7182.500000     36.000000
# 50%     5000.50000     40.000000      3.000000    11401.500000     57.000000
# 75%     7500.25000     49.000000      4.000000    15679.500000     78.000000
# max    10000.00000     59.000000      5.000000    19999.000000     99.000000
#
#        Years_at_Company  Years_in_Current_Role  Years_Since_Last_Promotion  \
# count      10000.000000           10000.000000                10000.000000
# mean          14.936200               7.451300                    4.471900
# ...

# %%
sns.boxplot(df['Monthly_Income'])
# Out:
# <Axes: ylabel='Monthly_Income'>

# %%
if ([df['Age'] < 0]):
    print("True")
# Out:
# True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Employee_ID                    10000 non-null  int64
#  1   Age                            10000 non-null  int64
#  2   Gender                         10000 non-null  object
#  3   Marital_Status                 10000 non-null  object
#  4   Department                     10000 non-null  object
#  5   Job_Role                       10000 non-null  object
#  6   Job_Level                      10000 non-null  int64
#  7   Monthly_Income                 10000 non-null  int64
#  8   Hourly_Rate                    10000 non-null  int64
#  9   Years_at_Company               10000 non-null  int64
#  10  Years_in_Current_Role          10000 non-null  int64
#  11  Years_Since_Last_Promotion     10000 non-null  int64
# ...

# %%
dd = df.drop(['Gender' ,'Marital_Status' ,'Department' ,'Job_Role' ,'Overtime','Employee_ID'] ,axis=1)

# %%
df.shape
# Out:
# (10000, 26)

# %%
def plot(cols):
    plt.figure(figsize=(8,5))
    plt.subplot(1,2,1)
    sns.boxplot(dd[cols])
    plt.subplot(1,2,2)
    sns.kdeplot(dd[cols])

# %%
# cols = df
for col in dd.columns:
    plot(col)
# plot(df['Monthly_Income'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 3
#       1 # cols = df
#       2 for col in dd.columns:
# ----> 3     plot(col)
#       4 # plot(df['Monthly_Income'])
#
# Cell In[63], line 6, in plot(cols)
#       4 sns.boxplot(dd[cols])
#       5 plt.subplot(1,2,2)
# ----> 6 sns.kdeplot(dd[cols])
#
# File ~/.local/lib/python3.8/site-packages/seaborn/distributions.py:1679, in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1676 if ax is None:
#    1677     ax = plt.gca()
# -> 1679 p._attach(ax, allowed_types=["numeric", "datetime"], log_scale=log_scale)
#    1681 method = ax.fill_between if fill else ax.plot
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Employee_ID                    1000 non-null   int64
#  1   Age                            1000 non-null   int64
#  2   Gender                         1000 non-null   object
#  3   Marital_Status                 1000 non-null   object
#  4   Department                     1000 non-null   object
#  5   Job_Role                       1000 non-null   object
#  6   Job_Level                      1000 non-null   int64
#  7   Monthly_Income                 1000 non-null   int64
#  8   Hourly_Rate                    1000 non-null   int64
#  9   Years_at_Company               1000 non-null   int64
#  10  Years_in_Current_Role          1000 non-null   int64
#  11  Years_Since_Last_Promotion     1000 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Employee_ID                      0
# Age                              0
# Gender                           0
# Marital_Status                   0
# Department                       0
# Job_Role                         0
# Job_Level                        0
# Monthly_Income                   0
# Hourly_Rate                      0
# Years_at_Company                 0
# Years_in_Current_Role            0
# Years_Since_Last_Promotion       0
# Work_Life_Balance                0
# Job_Satisfaction                 0
# Performance_Rating               0
# Training_Hours_Last_Year         0
# Overtime                         0
# Project_Count                    0
# Average_Hours_Worked_Per_Week    0
# Absenteeism                      0
# Work_Environment_Satisfaction    0
# Relationship_with_Manager        0
# Job_Involvement                  0
# Distance_From_Home               0
# Number_of_Companies_Worked       0
# Attrition                        0
# dtype: int64

# %%
df.head()
# Out:
#    Employee_ID  Age  Gender Marital_Status Department   Job_Role  Job_Level  \
# 0            1   58  Female        Married         IT    Manager          1
# 1            2   48  Female        Married      Sales  Assistant          5
# 2            3   34    Male        Married  Marketing  Assistant          1
# 3            4   27  Female       Divorced  Marketing    Manager          1
# 4            5   40    Male       Divorced  Marketing  Executive          1
#
#    Monthly_Income  Hourly_Rate  Years_at_Company  ...  Overtime  \
# 0           15488           28                15  ...        No
# 1           13079           28                 6  ...       Yes
# 2           13744           24                24  ...       Yes
# 3            6809           26                10  ...        No
# 4           10206           52                29  ...        No
#
#    Project_Count  Average_Hours_Worked_Per_Week  Absenteeism  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler

# Drop unnecessary columns
df.drop(columns=['Employee_ID', 'Hourly_Rate'], inplace=True)

# Encode categorical variables
categorical_cols = ['Gender', 'Marital_Status', 'Department', 'Job_Role', 'Overtime', 'Attrition']
label_encoders = {}

for col in categorical_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le  # Store encoders for future decoding

# Scale numerical features
scaler = StandardScaler()
numerical_cols = ['Age', 'Monthly_Income', 'Years_at_Company', 'Years_in_Current_Role',
                  'Years_Since_Last_Promotion', 'Work_Life_Balance', 'Job_Satisfaction',
                  'Performance_Rating', 'Training_Hours_Last_Year', 'Project_Count',
                  'Average_Hours_Worked_Per_Week', 'Absenteeism', 'Work_Environment_Satisfaction',
                  'Relationship_with_Manager', 'Job_Involvement', 'Distance_From_Home', 
                  'Number_of_Companies_Worked']

df[numerical_cols] = scaler.fit_transform(df[numerical_cols])

# Show processed dataset
df.head()
# Out:
#         Age  Gender  Marital_Status  Department  Job_Role  Job_Level  \
# 0  1.529535       0               1           2         3          1
# 1  0.680218       0               1           4         1          5
# 2 -0.508826       1               1           3         1          1
# 3 -1.103348       0               0           3         3          1
# 4  0.000764       1               0           3         2          1
#
#    Monthly_Income  Years_at_Company  Years_in_Current_Role  \
# 0        0.810908          0.009345              -0.884958
# 1        0.321082         -1.068968               0.365336
# 2        0.456297          1.087658               1.615630
# 3       -0.953809         -0.589717               0.115277
# 4       -0.263091          1.686721               0.615395
#
#    Years_Since_Last_Promotion  ...  Overtime  Project_Count  \
# 0                   -0.804387  ...         0       0.441160
# 1                   -1.138435  ...         1      -1.130204
# ...
